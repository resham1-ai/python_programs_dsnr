# %% [markdown]
# # conditional statements in python
# 1. python have 3 types of conditional statements
# 2. if statements
# 3. elif statements
# 4. else statements
#
# ```python
# if (logic):
#    statements
# else:
#     statements
# ```
#
# ``` python if,elif,else
# if(logic):
#     statements
# elif(logic):
#     statements
# elif(logic):
#     statements
# elif...
# else:
#     statements
# ```

# %%
num1=int(input("please enter a number: "))
num2=int(input("please enter a number :"))
num3=int(input("please enter a number:"))
if num1>=num2 and num1>=num3: 
        largest = num1 

elif num2>=num1 and num2>=num3:
        largest = num 
else:
    largest=num3 

print("the largest is ",largest)

# %%
num1=int(input("please enter a number: "))
num2=int(input("please enter a number :"))
num3=int(input("please enter a number:"))
if num1>=num2 and num1>=num3: 
    print("is largest number",num1) 

elif num2>=num1 and num2>=num3:
        print("is largest number",num2) 
else:
    print("is largest number",num3)
# Out:
# please enter a number:  23
# please enter a number : 34
# please enter a number: 56
# is largest number 56

# %%
num1=int(input("please enter a number: "))
num2=int(input("please enter a number :"))
num3=int(input("please enter a number:"))
if num1>=num2 and num1>=num3: 
    print("is largest number",num1) 

elif num2>=num1 and num2>=num3:
        print("is largest number",num2) 
else:
    print("is largest number",num3)
# Out:
# please enter a number:  34567
# please enter a number : 345678
# please enter a number: 123456789
# is largest number 123456789

# %%
print("welcome to calculation program")
num1=int(input("please enter a number"))
num2=int(input("please enter a number"))
option=int(input(" please select the operation below \n1.addition \n2.subraction \n3.division \n4.multiplication \n "))
if (option==1):
  print("addition of two numbers is ",num1+num2)
elif (option==2):
   print("subraction of two numbers is ",num1-num2)
elif (option==3):
    print("division of two numbers is ",num1/num2)
elif (option==4):
     print("multiplication of two numbers is ",num1*num2)
else:
     print("better luck next time")
# Out:
# welcome to calculation program
# please enter a number 2345678
# please enter a number 345678
#  please select the operation below
# 1.addition
# 2.subraction
# 3.division
# 4.multiplication
#   2345678
# better luck next time

# %%
username=str(input("please enter username here:"))
if (username=="sivaji123"):
    print("username is valid")
    pwd=str(input("please enter your password here:"))
    if(pwd=="s@12345"):
        print("your password is valid ")
        print(username,"welcome to python workshop")
    else:
        print("password is invalid, please check again")
else:
    print("usernameis invalid , please check again ")
# Out:
# please enter username here: sivaji123
# username is valid
# please enter your password here: s@12345
# your password is valid
# sivaji123 welcome to python workshop
